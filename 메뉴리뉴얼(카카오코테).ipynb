# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'''
1번 손님 A,B,C,F,G
2번 손님 A,C
3번 손님 C,D,E
4번 손님 A,C,D,E
5번 손님 B,C,F,G
6번 손님 A,C,D,E,H

코스 종류       메뉴구성    설명
요리 2개 코스   A,C      > 4번 주문
요리 3개 코스   C,D,E    > 3번 주문
요리 4개 코스   B,C,F,G  > 2번 주문
요리 4개 코스   A,C,D,E  > 2번 주문

orders = [  ## 입력내용
  ["ABCFG", "AC", "CDE", "ACDE", "BCFG", "ACDEH"],
  ["ABCDE", "AB", "CD", "ADE", "XYZ", "XYZ", "ACD"],
  ["XYZ", "XWY", "WXA"]
]
course = [  ## 입력내용
  [2,3,4],
  [2,3,5],
  [2,3,4]
]
result = [  ## 출력 내용
  [AC, ACDE, BCFG, CDE],
  [ACD, AD, ADE, CD, XYZ],
  [WX, XY]
]

'''

# %%
from itertools import combinations

def solution(orders, course):
  answer = []
  foodMap = [{} for _ in range(11)]
  maxCnt = [0 for _ in range(11)]

  for str in orders:
    for num in range(2, len(str) + 1):
      for i in combinations(sorted(str), num):
        key = ''.join(i)
        if key in foodMap[num]:
          foodMap[num][key] += 1
          maxCnt[num] = max(maxCnt[num], foodMap[num][key])
        else:
          foodMap[num][key] = 1

  for num in course:
    for key, value in foodMap[num].items():
      if value >= 2 and value == maxCnt[num]:
        answer.append(key)
  
  return sorted(answer)

orders = [
  ["ABCFG", "AC", "CDE", "ACDE", "BCFG", "ACDEH"],
  ["ABCDE", "AB", "CD", "ADE", "XYZ", "XYZ", "ACD"],
  ["XYZ", "XWY", "WXA"]
]
course = [
  [2,3,4],
  [2,3,5],
  [2,3,4]
]

for i in range(3):
  print(solution(orders[i], course[i]))
# Out:
# ['AC', 'ACDE', 'BCFG', 'CDE']
# ['ACD', 'AD', 'ADE', 'CD', 'XYZ']
# ['WX', 'XY']

# %%
from itertools import combinations
orders = [
  ["ABCFG", "AC", "CDE", "ACDE", "BCFG", "ACDEH"],
  ["ABCDE", "AB", "CD", "ADE", "XYZ", "XYZ", "ACD"],
  ["XYZ", "XWY", "WXA"]
]

answer = []
foodMap = [{} for _ in range(11)]
maxCnt = [0 for _ in range(11)]

for str in orders:
  for num in range(2, len(str) + 1):
    for i in combinations(sorted(str), num):
      key = ''.join(i)
      if key in foodMap[num]:
        foodMap[num][key] += 1
        maxCnt[num] = max(maxCnt[num], foodMap[num][key])
      else:
        foodMap[num][key] = 1

# %%
# Combinations 직접 구현하기!!!
def comb(population,num):
	ans = []

  # 작동이 멈추는 경우 2가지 
  ## 정의된 값인지 확인한다.
	if num > len(population): return ans
	## Base Case
	if num == 1:
		for i in population:
			ans.append([i])
  # 위 조건에 아무것도 걸리지 않을 경우
  ## General Case
	elif num > 1:
    ## i가 시작하는 값 - len(population) - (n-1)이고 이 때 n은 lst로부터 추출할 개수와 같다.
		for i in range(len(population)-num+1): 
			for temp in comb(population[i+1:],num-1):
				ans.append([population[i]]+temp)

	return ans

# %%
def gen_combinations(arr, n): 
  result =[]

  if n == 0: 
    return [[]]

  for i in range(0, len(arr)): 
    elem = arr[i] 
    rest_arr = arr[(i+1):] 

    for C in gen_combinations(rest_arr, n-1): 
      result.append([elem]+C) 
      
  return result

arr = [0, 1, 2, 3, 4, 5]
print(gen_combinations(arr,3))

# %%
def choose(n,k): 
  if k == 0: 
    return 1 
  elif n < k: 
    return 0 
  else: 
    return choose(n-1, k-1) + choose(n-1, k) print(choose(10,2))
